# %%
import pandas as pd
import seaborn as sb
sb.set()

# %% [markdown]
# ### Load data

# %%
temp = pd.read_json("./data.json")
df = pd.json_normalize(temp['data'])
df.head()
# Out:
#       id                         title  \
# 0   2076  Kindaichi Shounen no Jikenbo
# 1   3371   Ginga Eiyuu Densetsu Gaiden
# 2  37779         Yakusoku no Neverland
# 3   2150          Tanoshii Muumin Ikka
# 4  27947              Lupin III (2015)
#
#                                          description  \
# 0  Hajime Kindaichi's unorganized appearance and ...
# 1  Ginga Eiyuu Densetsu Gaiden is the first of tw...
# 2  Surrounded by a forest and a gated entrance, t...
# 3  Spring has finally arrived in Moomin Valley, g...
# 4  Lupin is the main character in this series whi...
#
#                                                image  rank  mean_score  life  \
# 0  https://api-cdn.myanimelist.net/images/anime/1...   637        7.95     7
# 1  https://api-cdn.myanimelist.net/images/anime/9...   402        8.13     6
# 2  https://api-cdn.myanimelist.net/images/anime/1...   100        8.54     7
# 3  https://api-cdn.myanimelist.net/images/anime/1...   331        8.20     6
# 4  https://api-cdn.myanimelist.net/images/anime/9...   716        7.90     6
#
#             status                                             genres  \
# 0  finished_airing                                    Mystery,Shounen
# 1  finished_airing                 Action,Drama,Military,Sci-Fi,Space
# 2  finished_airing  Mystery,Psychological,Sci-Fi,Shounen,Survival,...
# 3  finished_airing  Adventure,Comedy,Fantasy,Iyashikei,Kids,Slice ...
# 4  finished_airing  Action,Adult Cast,Adventure,Comedy,Mystery,Seinen
#
#   media_type  release_year        date
# 0         tv          1997  2022-06-26
# 1        ova          1998  2022-06-27
# 2         tv          2019  2022-06-28
# 3         tv          1990  2022-06-29
# 4         tv          2015  2022-06-30

# %% [markdown]
# ### Pre-process

# %%
df['letter_count'] = df.apply(lambda row: len(row['title']), axis=1)
df['unique_letter_count'] = df.apply(lambda row: len(set(row["title"].lower())), axis=1)
df.head()
# Out:
#       id                         title  \
# 0   2076  Kindaichi Shounen no Jikenbo
# 1   3371   Ginga Eiyuu Densetsu Gaiden
# 2  37779         Yakusoku no Neverland
# 3   2150          Tanoshii Muumin Ikka
# 4  27947              Lupin III (2015)
#
#                                          description  \
# 0  Hajime Kindaichi's unorganized appearance and ...
# 1  Ginga Eiyuu Densetsu Gaiden is the first of tw...
# 2  Surrounded by a forest and a gated entrance, t...
# 3  Spring has finally arrived in Moomin Valley, g...
# 4  Lupin is the main character in this series whi...
#
#                                                image  rank  mean_score  life  \
# 0  https://api-cdn.myanimelist.net/images/anime/1...   637        7.95     7
# 1  https://api-cdn.myanimelist.net/images/anime/9...   402        8.13     6
# 2  https://api-cdn.myanimelist.net/images/anime/1...   100        8.54     7
# 3  https://api-cdn.myanimelist.net/images/anime/1...   331        8.20     6
# 4  https://api-cdn.myanimelist.net/images/anime/9...   716        7.90     6
#
#             status                                             genres  \
# 0  finished_airing                                    Mystery,Shounen
# 1  finished_airing                 Action,Drama,Military,Sci-Fi,Space
# 2  finished_airing  Mystery,Psychological,Sci-Fi,Shounen,Survival,...
# 3  finished_airing  Adventure,Comedy,Fantasy,Iyashikei,Kids,Slice ...
# 4  finished_airing  Action,Adult Cast,Adventure,Comedy,Mystery,Seinen
#
#   media_type  release_year        date  letter_count  unique_letter_count
# 0         tv          1997  2022-06-26            28                   14
# 1        ova          1998  2022-06-27            27                   11
# 2         tv          2019  2022-06-28            21                   13
# 3         tv          1990  2022-06-29            20                   11
# 4         tv          2015  2022-06-30            16                   12

# %% [markdown]
# ### Graphs

# %%
sb.histplot(data=df, x="letter_count", kde=True).set(title= "letter count")
# Out:
# [Text(0.5, 1.0, 'letter count')]

# %%
sb.boxplot(data=df, x="media_type", y="letter_count").set(title= "letter count")
# Out:
# [Text(0.5, 1.0, 'letter count')]

# %%
sb.histplot(data=df, x="letter_count", hue="media_type", multiple="stack")
# Out:
# <AxesSubplot:xlabel='letter_count', ylabel='Count'>

# %%
sb.histplot(data=df, x="unique_letter_count", kde=True).set(title="unique letter count")
# Out:
# [Text(0.5, 1.0, 'unique letter count')]

# %%
sb.histplot(data=df, x="release_year", kde=True).set(title="Anime Released")
# Out:
# [Text(0.5, 1.0, 'Anime Released')]

# %%
sb.histplot(data=df, x="media_type", hue="media_type", stat="percent").set(title="media type")
# Out:
# [Text(0.5, 1.0, 'media type')]
